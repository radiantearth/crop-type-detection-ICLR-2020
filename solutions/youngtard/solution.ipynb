# %% [markdown]
# # Data was generated based on the Starter Notebook created by John Whitaker (JW)
# https://colab.research.google.com/drive/1DPizsNT7GUK776TRDmk5rZVMsB1kJY5H

# %%
import tifffile as tiff
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import glob
import datetime
from tqdm.notebook import tqdm

import sklearn

from sklearn.utils.class_weight import compute_class_weight

from sklearn.inspection import permutation_importance
from scipy.stats.mstats import gmean

# Models
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import BaggingClassifier
import catboost
from catboost import CatBoostClassifier

import eli5
from eli5.sklearn import PermutationImportance

from sklearn.model_selection import cross_val_predict, train_test_split
from sklearn.metrics import log_loss

import os

# %% [markdown]
# # Package versions

# %%
catboost.__version__ #0.22
# Out:
# '0.22'

# %%
sklearn.__version__ #0.22.2
# Out:
# '0.22.2'

# %%
eli5.__version__ #0.10.1

# %%
dates_raw = [
datetime.datetime(2019, 6, 6, 0, 0),
datetime.datetime(2019, 7, 1, 0, 0),
datetime.datetime(2019, 7, 6, 0, 0),
datetime.datetime(2019, 7, 11, 0, 0),
datetime.datetime(2019, 7, 21, 0, 0),
datetime.datetime(2019, 8, 5, 0, 0),
datetime.datetime(2019, 8, 15, 0, 0),
datetime.datetime(2019, 8, 25, 0, 0),
datetime.datetime(2019, 9, 9, 0, 0),
datetime.datetime(2019, 9, 19, 0, 0),
datetime.datetime(2019, 9, 24, 0, 0),
datetime.datetime(2019, 10, 4, 0, 0),
datetime.datetime(2019, 11, 3, 0, 0)
]

dates = []

for i in range(13):
    dt = "".join(str(dates_raw[i].date()).split("-"))
    dates.append(dt)

# %%
bands = ['B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B8A', 'B09', 'B11', 'B12']

# %%
# Including Cloud Layer
bands_all = ['B01', 'B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'B08', 'B8A', 'B09', 'B11', 'B12', 'CLD']

# %% [markdown]
# # DATA GENERATION - based on JW starter code
# > NB: Directory of competition data (multi spectral satellite images) should be named "data", and all relevant images should be included in their respective tile folder and sub folders

# %%
def load_file(fp):
    """Takes a PosixPath object or string filepath
    and returns np array"""
    
    return tiff.imread(fp.__str__())

# %%
row_locs = []
col_locs = []
field_ids = []
labels = []
tiles = []

for tile in range(4):
    fids = f'data/0{tile}/{tile}_field_id.tif'
    labs = f'data/0{tile}/{tile}_label.tif'
    fid_arr = load_file(fids)
    lab_arr = load_file(labs)
    for row in range(len(fid_arr)):
    for col in range(len(fid_arr[0])):
        if fid_arr[row][col] != 0:
            row_locs.append(row)
            col_locs.append(col)
            field_ids.append(fid_arr[row][col])
            labels.append(lab_arr[row][col])
            tiles.append(tile)

# %%
df_generated = pd.DataFrame({
    'fid':field_ids,
    'label':labels,
    'row_loc': row_locs,
    'col_loc':col_locs,
    'tile':tiles
})

# %%
df_generated.head()
# Out:
#     fid  label  row_loc  col_loc  tile
# 0  2928      4      214     1278     0
# 1  2928      4      214     1279     0
# 2  2928      4      214     1280     0
# 3  2928      4      214     1281     0
# 4  2928      4      214     1282     0

# %%
df_generated.shape
# Out:
# (67557, 5)

# %%
col_names = []
col_values = []

for tile in range(4): # 1) For each tile
    print('Tile: ', tile)
    for d in dates: # 2) For each date
        print(str(d))
#         d = ''.join(str(d.date()).split('-')) # Nice date string
        t = '0' + str(tile)
        for b in bands_all: # 3) For each band
            col_name = d + '_' + b

            if tile == 0:
                # If the column doesn't exist, create it and populate with 0s
                df_generated[col_name] = 0

            # Load im
            im = load_file(f"data/{t}/{d}/{t[1]}_{b}_{d}.tif")

            # Going four levels deep. Each second on the outside is four weeks in this loop
            # If we die here, there's no waking up.....
            vals = []
            for row, col in df_generated.loc[df_generated.tile == tile][['row_loc', 'col_loc']].values: # 4) For each location of a pixel in a field
                vals.append(im[row][col])
            df_generated.loc[df_generated.tile == tile, col_name] = vals
# Out:
# Tile:  0
# 20190606
# 20190701
# 20190706
# 20190711
# 20190721
# 20190805
# 20190815
# 20190825
# 20190909
# 20190919
# 20190924
# 20191004
# 20191103
# Tile:  1
# 20190606
# 20190701
# 20190706
# 20190711
# 20190721
# 20190805
# 20190815
# 20190825
# 20190909
# 20190919
# 20190924
# 20191004
# 20191103
# Tile:  2
# 20190606
# 20190701
# 20190706
# 20190711
# 20190721
# 20190805
# 20190815
# 20190825
# 20190909
# 20190919
# 20190924
# 20191004
# 20191103
# Tile:  3
# 20190606
# 20190701
# 20190706
# 20190711
# 20190721
# 20190805
# 20190815
# 20190825
# 20190909
# 20190919
# 20190924
# 20191004
# 20191103

# %%
df_generated.head()
# Out:
#     fid  label  row_loc  col_loc  tile  20190606_B01  20190606_B02  \
# 0  2928      4      214     1278     0        0.1995        0.2024
# 1  2928      4      214     1279     0        0.1995        0.1942
# 2  2928      4      214     1280     0        0.1995        0.1868
# 3  2928      4      214     1281     0        0.1995        0.1962
# 4  2928      4      214     1282     0        0.1995        0.1976
#
#    20190606_B03  20190606_B04  20190606_B05  ...  20191103_B04  20191103_B05  \
# 0        0.1782        0.1898        0.2462  ...        0.0669        0.1239
# 1        0.1848        0.1846        0.2462  ...        0.0603        0.1239
# 2        0.1930        0.1860        0.2558  ...        0.0631        0.1259
# 3        0.1978        0.1954        0.2558  ...        0.1214        0.1259
# 4        0.1914        0.1956        0.2571  ...        0.1278        0.1385
#
#    20191103_B06  20191103_B07  20191103_B08  20191103_B8A  20191103_B09  \
# 0        0.2660        0.3214        0.3204        0.3515         0.361
# 1        0.2660        0.3214        0.3296        0.3515         0.361
# 2        0.2579        0.3131        0.3459        0.3307         0.361
# 3        0.2579        0.3131        0.2861        0.3307         0.361
# 4        0.2726        0.3239        0.3286        0.3446         0.361
#
#    20191103_B11  20191103_B12  20191103_CLD
# 0        0.2362        0.1347           0.0
# 1        0.2362        0.1347           0.0
# 2        0.2304        0.1471           0.0
# 3        0.2304        0.1471           0.0
# 4        0.2323        0.1355           0.0
#
# [5 rows x 174 columns]

# %%
df_generated.shape
# Out:
# (67557, 174)

# %%
df_generated.to_csv("data/bands_ungrouped.csv", index = False)

# %% [markdown]
# # Import data
# > NB: The above "Data Generation" code is preliminary. The data generated isn't used directly, but rather exported to .csv format, and imported below for further usage

# %%
sample_submission = pd.read_csv("data/SampleSubmission.csv")

# %%
df_ungrouped = pd.read_csv("data/bands_ungrouped.csv")

# %%
df_ungrouped.head()
# Out:
#     fid  label  row_loc  col_loc  tile  20190606_B01  20190606_B02  \
# 0  2928      4      214     1278     0        0.1995        0.2024
# 1  2928      4      214     1279     0        0.1995        0.1942
# 2  2928      4      214     1280     0        0.1995        0.1868
# 3  2928      4      214     1281     0        0.1995        0.1962
# 4  2928      4      214     1282     0        0.1995        0.1976
#
#    20190606_B03  20190606_B04  20190606_B05  ...  20191103_B04  20191103_B05  \
# 0        0.1782        0.1898        0.2462  ...        0.0669        0.1239
# 1        0.1848        0.1846        0.2462  ...        0.0603        0.1239
# 2        0.1930        0.1860        0.2558  ...        0.0631        0.1259
# 3        0.1978        0.1954        0.2558  ...        0.1214        0.1259
# 4        0.1914        0.1956        0.2571  ...        0.1278        0.1385
#
#    20191103_B06  20191103_B07  20191103_B08  20191103_B8A  20191103_B09  \
# 0        0.2660        0.3214        0.3204        0.3515         0.361
# 1        0.2660        0.3214        0.3296        0.3515         0.361
# 2        0.2579        0.3131        0.3459        0.3307         0.361
# 3        0.2579        0.3131        0.2861        0.3307         0.361
# 4        0.2726        0.3239        0.3286        0.3446         0.361
#
#    20191103_B11  20191103_B12  20191103_CLD
# 0        0.2362        0.1347           0.0
# 1        0.2362        0.1347           0.0
# 2        0.2304        0.1471           0.0
# 3        0.2304        0.1471           0.0
# 4        0.2323        0.1355           0.0
#
# [5 rows x 174 columns]

# %%
df_ungrouped.shape
# Out:
# (67557, 174)

# %% [markdown]
# # DATA PREPARATION/PRE-PROCESSING

# %%
# Spatial features to be merged with dataset (by Field ID) later on
row_size = df_ungrouped.groupby("fid")["row_loc"].nunique()
column_size = df_ungrouped.groupby("fid")["col_loc"].nunique()
num_pixels = df_ungrouped.groupby("fid")["label"].count()

# %%
# Grouped Data
df_grouped = df_ungrouped.groupby("fid", as_index = False).mean()

# %% [markdown]
# ### Two separate modelling was done on different set of features, and later combined through ensembling
# > ### 1st modelling
# Features used:
# 1. Pixel values of each of the 12 bands, INCLUDING the cloud probabilities (for the 13 timestamps)
# 2. Vegetation/Spectral indices like NDVI, GNDVI, AVI etc, and relevant statistics related to the indices like mean, max etc.
# 3. Spatial features - row_size, column_size (both indicating height, and width), area of field, and number of pixels covered by a field in the area computed
#
# Relevant code variables are usually suffixed with "_all"
#
# > ### 2nd modelling  (Pixel related)
# Features used:
# 1. Pixel values of each of the 12 bands, EXCLUDING the cloud probabilities (for the 13 timestamps)
# 2. Statistics related to pixel values of each band like mean, max etc.
#
# Relevant code variables are usually suffixed with "_pixels"

# %%
# Dataframe for 1st modelling
df_all = df_grouped.copy()

# %%
# Dataframe for 2nd modelling
df_pixels = df_grouped.copy()

# %%
# Drop non-allowed features. Field ID is dropped later on as it's still needed for further processing
df_all = df_all.drop(columns = ["row_loc", "col_loc", "tile"])
df_pixels = df_pixels.drop(columns = ["row_loc", "col_loc", "tile"])

# %%
cloud_columns = ['20190606_CLD', '20190701_CLD', '20190706_CLD', '20190711_CLD', '20190721_CLD', '20190805_CLD', '20190815_CLD', '20190825_CLD', '20190909_CLD', '20190919_CLD', '20190924_CLD', '20191004_CLD', '20191103_CLD']

# %%
# Drop Cloud probabilities, and Field ID's in 2nd Dataframe.
# Field ID in 1st Dataframe will be dropped later
df_pixels.drop(columns = cloud_columns + ["fid"], inplace = True)

# %%
df_all.head()
# Out:
#    fid  label  20190606_B01  20190606_B02  20190606_B03  20190606_B04  \
# 0    1    1.0      0.098600      0.078200      0.108000      0.098600
# 1    2    2.0      0.037855      0.058818      0.086627      0.060945
# 2    3    0.0      0.260700      0.264511      0.232378      0.196911
# 3    4    2.0      0.027792      0.033031      0.060354      0.047331
# 4    5    5.0      0.014600      0.022500      0.035400      0.030200
#
#    20190606_B05  20190606_B06  20190606_B07  20190606_B08  ...  20191103_B04  \
# 0      0.158100      0.309400      0.366800      0.355400  ...      0.102800
# 1      0.119536      0.275473      0.325918      0.316755  ...      0.096155
# 2      0.229033      0.301122      0.333367      0.349678  ...      0.446889
# 3      0.103085      0.260508      0.320369      0.297408  ...      0.073946
# 4      0.063400      0.154400      0.185300      0.186800  ...      0.064100
#
#    20191103_B05  20191103_B06  20191103_B07  20191103_B08  20191103_B8A  \
# 0      0.147200      0.263700      0.305800      0.299400      0.320000
# 1      0.171527      0.323836      0.372173      0.379673      0.410027
# 2      0.488256      0.522944      0.526311      0.625122      0.521933
# 3      0.158177      0.341762      0.392846      0.394592      0.419885
# 4      0.134400      0.286200      0.344500      0.333900      0.357100
#
#    20191103_B09  20191103_B11  20191103_B12  20191103_CLD
# 0      0.329700      0.252700      0.153500           0.0
# 1      0.408255      0.323173      0.207200           0.0
# 2      0.696400      0.546033      0.435767         100.0
# 3      0.402800      0.310362      0.200377           0.0
# 4      0.352600      0.213900      0.126100           0.0
#
# [5 rows x 171 columns]

# %%
df_pixels.head()
# Out:
#    label  20190606_B01  20190606_B02  20190606_B03  20190606_B04  \
# 0    1.0      0.098600      0.078200      0.108000      0.098600
# 1    2.0      0.037855      0.058818      0.086627      0.060945
# 2    0.0      0.260700      0.264511      0.232378      0.196911
# 3    2.0      0.027792      0.033031      0.060354      0.047331
# 4    5.0      0.014600      0.022500      0.035400      0.030200
#
#    20190606_B05  20190606_B06  20190606_B07  20190606_B08  20190606_B8A  ...  \
# 0      0.158100      0.309400      0.366800      0.355400      0.391000  ...
# 1      0.119536      0.275473      0.325918      0.316755      0.348482  ...
# 2      0.229033      0.301122      0.333367      0.349678      0.340689  ...
# 3      0.103085      0.260508      0.320369      0.297408      0.338000  ...
# 4      0.063400      0.154400      0.185300      0.186800      0.187600  ...
#
#    20191103_B03  20191103_B04  20191103_B05  20191103_B06  20191103_B07  \
# 0      0.104200      0.102800      0.147200      0.263700      0.305800
# 1      0.109055      0.096155      0.171527      0.323836      0.372173
# 2      0.510644      0.446889      0.488256      0.522944      0.526311
# 3      0.093308      0.073946      0.158177      0.341762      0.392846
# 4      0.088300      0.064100      0.134400      0.286200      0.344500
#
#    20191103_B08  20191103_B8A  20191103_B09  20191103_B11  20191103_B12
# 0      0.299400      0.320000      0.329700      0.252700      0.153500
# 1      0.379673      0.410027      0.408255      0.323173      0.207200
# 2      0.625122      0.521933      0.696400      0.546033      0.435767
# 3      0.394592      0.419885      0.402800      0.310362      0.200377
# 4      0.333900      0.357100      0.352600      0.213900      0.126100
#
# [5 rows x 157 columns]

# %% [markdown]
# ### Vegetation/Spectral indices

# %% [markdown]
# 1. Normalized Difference Vegetation Index (NDVI)
# 2. Green Normalized Difference Vegetation Index (GNDVI)
# 3. Enhanced Vegetation Index (EVI)
# 4. Enhanced Vegetation Index 2 (EVI2)
# 5. Advanced Vegetation Index (AVI)
# 6. Bare Soil Index (BSI)
# 7. Shadow Index (SI)
# 8. Normalized Difference Water Index (NDWI)
# 9. Normalized Difference Moisture Index (NDMI)
# 10. Normalized Pigment Chlorophyll Ratio Index (NPCRI)

# %%
spectral_indices = ["NDVI", "GNDVI", "EVI", "EVI2", "AVI", "BSI", "SI", "NDWI", "NDMI", "NPCRI"]

# %%
for i in range(13):
#     Band Pixel values per timestamp
    b1 = df_all.filter(like = "B01").values[:,i]
    b2 = df_all.filter(like = "B02").values[:,i]
    b3 = df_all.filter(like = "B03").values[:,i]
    b4 = df_all.filter(like = "B04").values[:,i]
    b5 = df_all.filter(like = "B05").values[:,i]
    b6 = df_all.filter(like = "B06").values[:,i]
    b7 = df_all.filter(like = "B07").values[:,i]
    b8 = df_all.filter(like = "B08").values[:,i]
    b8a = df_all.filter(like = "B8A").values[:,i]
    b9 = df_all.filter(like = "B09").values[:,i]    
    b11 = df_all.filter(like = "B11").values[:,i]
    b12 = df_all.filter(like = "B12").values[:,i]
    
#     Computation of indices
    ndvi = (b8 - b4) / (b8 + b4)
    gndvi = (b8 - b3) / (b8 + b3)
    evi = 2.5 * (b8 - b4) / ((b8 + 6.0 * b4 - 7.5 * b2) + 1.0)    
    evi2 = 2.4 * (b8 - b4) / (b8 + b4 + 1.0)
    avi = (b8 * (1 - b4) * (b8 - b4))
    bsi = ((b11 + b4) - (b8 + b2)) / ((b11 + b4) + (b8 + b2))
    si = ((1 - b2) * (1 - b3) * (1 - b4))
    ndwi = (b3 - b8) / (b3 + b8)
    ndmi = (b8 - b11) / (b8 + b11)
    npcri = (b4 - b2) / (b4 + b2) 
    
#     Add indices as features to 1st dataframe per timestamp
    df_all[f'NDVI_{dates[i]}'] = ndvi 
    df_all[f'GNDVI_{dates[i]}'] = gndvi
    df_all[f'EVI_{dates[i]}'] = evi
    df_all[f'EVI2_{dates[i]}'] = evi2
    df_all[f'AVI_{dates[i]}'] = avi
    df_all[f'BSI_{dates[i]}'] = bsi
    df_all[f'SI_{dates[i]}'] = si    
    df_all[f'NDWI_{dates[i]}'] = ndwi
    df_all[f'NDMI_{dates[i]}'] = ndmi
    df_all[f'NPCRI_{dates[i]}'] = npcri

# %%
# Add spectral indices statistics related to 1st dataframe
for i in spectral_indices:
    df_all[f'{i}_min'] = df_all.filter(regex = f'^{i}').min(axis = 1)
    df_all[f'{i}_max'] = df_all.filter(regex = f'^{i}').max(axis = 1)
    df_all[f'{i}_avg'] = df_all.filter(regex = f'^{i}').mean(axis = 1)
    df_all[f'{i}_std'] = df_all.filter(regex = f'^{i}').std(axis = 1)

# %%
# Add band pixel values statistics related to 2nd dataframe
for i in bands:
    df_pixels[f'{i}_std'] = df_pixels.filter(like = f'_{i}').std(axis = 1)
    df_pixels[f'{i}_max'] = df_pixels.filter(like = f'_{i}').max(axis = 1)
    df_pixels[f'{i}_min'] = df_pixels.filter(like = f'_{i}').min(axis = 1)
    df_pixels[f'{i}_avg'] = df_pixels.filter(like = f'_{i}').mean(axis = 1)

# %%
# NB: "new_df" represents 1st dataframe
new_df = df_all.copy()

# %% [markdown]
# ## Spatial statistics - used in first dataframe

# %%
new_df["row_size"] = new_df.fid.map(row_size)
new_df["col_size"] = new_df.fid.map(column_size)
new_df["area"] = new_df.apply(lambda row: row.row_size * row.col_size, axis = 1)
# number of pixels covered by a field in the area computed
new_df["num_pixels"] = new_df.fid.map(num_pixels)

# %%
# Drop non-allowed Field ID in 1st dataframe
new_df = new_df.drop(columns = ["fid"])

# %% [markdown]
# ## Train, and Test set generation

# %%
# 1st dataframe
df_all_train = new_df[new_df.label != 0].copy()
df_all_test = new_df[new_df.label == 0].copy()

df_all_train = df_all_train.reset_index(drop = True)
df_all_test = df_all_test.reset_index(drop = True)

# %%
# 2nd dataframe
df_pixels_train = df_pixels[df_pixels.label != 0].copy()
df_pixels_test = df_pixels[df_pixels.label == 0].copy()

df_pixels_train = df_pixels_train.reset_index(drop = True)
df_pixels_test = df_pixels_test.reset_index(drop = True)

# %%
(df_all_train.shape, df_all_test.shape), (df_pixels_train.shape, df_pixels_test.shape)
# Out:
# (((3286, 344), (1402, 344)), ((3286, 205), (1402, 205)))

# %%
# Drop crop labels (0) from test sets
df_all_test.drop("label", inplace = True, axis = 1)
df_pixels_test.drop("label", inplace = True, axis = 1)

# %% [markdown]
# ## Train X, and y generation (Features, and Target/Label)

# %%
# 1st dataframe
train_X_all = df_all_train.drop("label", axis = 1)
train_y_all = df_all_train.label

# %%
# 2nd dataframe
train_X_pixels = df_pixels_train.drop("label", axis = 1)
train_y_pixels = df_pixels_train.label

# %%
train_X_all.shape, df_all_test.shape
# Out:
# ((3286, 343), (1402, 343))

# %%
train_X_pixels.shape, df_pixels_test.shape
# Out:
# ((3286, 204), (1402, 204))

# %% [markdown]
# ## Class/Label weights

# %%
# Class weights for cross validation
# Cross validation weights are based on 80% of train set
X_trn, X_val, y_trn, y_val = train_test_split(train_X_all, train_y_all, test_size = 0.2, stratify = train_y_all, random_state = 5, shuffle = True)
label_weights1 = compute_class_weight("balanced", np.unique(y_trn), y_trn)

# %%
# Class weights for full training
# Cross validation weights are based on full train set
label_weights2 = compute_class_weight("balanced", np.unique(train_y_all), train_y_all)

# %% [markdown]
# ## Permutation Importance for Feature Selection
# > NB: Feature selection/dropping was only carried out on 1st dataframe

# %%
# cb_pi --> catboost_permutation_importance
cb_pi = CatBoostClassifier(n_estimators = 1400, learning_rate = 0.03, random_state = 11, task_type = "GPU")
cb_pi.fit(X_trn, y_trn)
# Out:
# 0:	learn: 1.9110878	total: 32.7ms	remaining: 45.8s
# 1:	learn: 1.8784226	total: 46.5ms	remaining: 32.5s
# 2:	learn: 1.8497764	total: 64.7ms	remaining: 30.1s
# 3:	learn: 1.8228234	total: 78.2ms	remaining: 27.3s
# 4:	learn: 1.7973512	total: 91.6ms	remaining: 25.5s
# 5:	learn: 1.7730135	total: 105ms	remaining: 24.3s
# 6:	learn: 1.7504011	total: 118ms	remaining: 23.5s
# 7:	learn: 1.7282823	total: 132ms	remaining: 22.9s
# 8:	learn: 1.7073400	total: 145ms	remaining: 22.4s
# 9:	learn: 1.6875321	total: 159ms	remaining: 22s
# 10:	learn: 1.6692760	total: 172ms	remaining: 21.7s
# 11:	learn: 1.6521108	total: 185ms	remaining: 21.4s
# 12:	learn: 1.6359421	total: 198ms	remaining: 21.2s
# 13:	learn: 1.6208647	total: 212ms	remaining: 20.9s
# 14:	learn: 1.6064373	total: 230ms	remaining: 21.2s
# 15:	learn: 1.5917729	total: 243ms	remaining: 21s
# 16:	learn: 1.5786597	total: 256ms	remaining: 20.8s
# 17:	learn: 1.5654139	total: 268ms	remaining: 20.6s
# 18:	learn: 1.5529085	total: 281ms	remaining: 20.5s
# 19:	learn: 1.5407589	total: 294ms	remaining: 20.3s
# 20:	learn: 1.5293600	total: 307ms	remaining: 20.2s
# 21:	learn: 1.5177492	total: 320ms	remaining: 20s
# 22:	learn: 1.5075279	total: 332ms	remaining: 19.9s
# 23:	learn: 1.4979014	total: 345ms	remaining: 19.8s
# 24:	learn: 1.4875649	total: 358ms	remaining: 19.7s
# 25:	learn: 1.4788417	total: 371ms	remaining: 19.6s
# 26:	learn: 1.4696309	total: 384ms	remaining: 19.5s
# 27:	learn: 1.4609570	total: 401ms	remaining: 19.6s
# 28:	learn: 1.4517946	total: 414ms	remaining: 19.6s
# 29:	learn: 1.4439443	total: 427ms	remaining: 19.5s
# 30:	learn: 1.4363157	total: 443ms	remaining: 19.5s
# 31:	learn: 1.4286362	total: 455ms	remaining: 19.5s
# 32:	learn: 1.4210186	total: 468ms	remaining: 19.4s
# 33:	learn: 1.4135332	total: 481ms	remaining: 19.3s
# 34:	learn: 1.4065591	total: 493ms	remaining: 19.2s
# 35:	learn: 1.3993560	total: 506ms	remaining: 19.2s
# 36:	learn: 1.3934239	total: 519ms	remaining: 19.1s
# 37:	learn: 1.3871684	total: 532ms	remaining: 19.1s
# 38:	learn: 1.3813686	total: 544ms	remaining: 19s
# 39:	learn: 1.3752914	total: 557ms	remaining: 18.9s
# 40:	learn: 1.3692258	total: 570ms	remaining: 18.9s
# 41:	learn: 1.3637363	total: 582ms	remaining: 18.8s
# 42:	learn: 1.3585272	total: 595ms	remaining: 18.8s
# 90:	learn: 1.2008168	total: 1.23s	remaining: 17.7s
# 91:	learn: 1.1986060	total: 1.25s	remaining: 17.7s
# 92:	learn: 1.1963188	total: 1.26s	remaining: 17.7s
# 93:	learn: 1.1944524	total: 1.27s	remaining: 17.7s
# 94:	learn: 1.1922414	total: 1.29s	remaining: 17.7s
# 95:	learn: 1.1904865	total: 1.3s	remaining: 17.6s
# 96:	learn: 1.1889806	total: 1.31s	remaining: 17.6s
# 97:	learn: 1.1873083	total: 1.32s	remaining: 17.6s
# 98:	learn: 1.1851016	total: 1.34s	remaining: 17.6s
# 99:	learn: 1.1835637	total: 1.35s	remaining: 17.6s
# 100:	learn: 1.1809095	total: 1.36s	remaining: 17.5s
# 101:	learn: 1.1792509	total: 1.38s	remaining: 17.5s
# 102:	learn: 1.1775411	total: 1.39s	remaining: 17.5s
# 103:	learn: 1.1755122	total: 1.4s	remaining: 17.5s
# 104:	learn: 1.1736843	total: 1.42s	remaining: 17.5s
# 105:	learn: 1.1722744	total: 1.43s	remaining: 17.4s
# 106:	learn: 1.1703903	total: 1.44s	remaining: 17.4s
# 107:	learn: 1.1686132	total: 1.45s	remaining: 17.4s
# 108:	learn: 1.1669205	total: 1.47s	remaining: 17.4s
# 109:	learn: 1.1655006	total: 1.48s	remaining: 17.4s
# 110:	learn: 1.1634573	total: 1.49s	remaining: 17.4s
# 111:	learn: 1.1612395	total: 1.51s	remaining: 17.3s
# 112:	learn: 1.1593495	total: 1.52s	remaining: 17.3s
# 113:	learn: 1.1572645	total: 1.53s	remaining: 17.3s
# 114:	learn: 1.1552869	total: 1.54s	remaining: 17.3s
# 115:	learn: 1.1537470	total: 1.56s	remaining: 17.3s
# 116:	learn: 1.1526597	total: 1.57s	remaining: 17.2s
# 117:	learn: 1.1511400	total: 1.58s	remaining: 17.2s
# 118:	learn: 1.1491147	total: 1.6s	remaining: 17.2s
# 119:	learn: 1.1476266	total: 1.61s	remaining: 17.2s
# 120:	learn: 1.1454664	total: 1.62s	remaining: 17.2s
# 121:	learn: 1.1439294	total: 1.64s	remaining: 17.1s
# 122:	learn: 1.1426289	total: 1.65s	remaining: 17.1s
# 123:	learn: 1.1413113	total: 1.66s	remaining: 17.1s
# 124:	learn: 1.1400923	total: 1.67s	remaining: 17.1s
# 125:	learn: 1.1385264	total: 1.69s	remaining: 17.1s
# 126:	learn: 1.1374472	total: 1.7s	remaining: 17.1s
# 127:	learn: 1.1351754	total: 1.72s	remaining: 17.1s
# 128:	learn: 1.1334219	total: 1.73s	remaining: 17.1s
# 129:	learn: 1.1320589	total: 1.74s	remaining: 17s
# 130:	learn: 1.1307411	total: 1.75s	remaining: 17s
# 131:	learn: 1.1294412	total: 1.77s	remaining: 17s
# 132:	learn: 1.1271346	total: 1.78s	remaining: 17s
# 133:	learn: 1.1253278	total: 1.79s	remaining: 16.9s
# 134:	learn: 1.1237003	total: 1.81s	remaining: 16.9s
# 135:	learn: 1.1219237	total: 1.82s	remaining: 16.9s
# 136:	learn: 1.1203382	total: 1.83s	remaining: 16.9s
# 137:	learn: 1.1192408	total: 1.84s	remaining: 16.9s
# 138:	learn: 1.1177984	total: 1.86s	remaining: 16.8s
# 139:	learn: 1.1163024	total: 1.87s	remaining: 16.8s
# 140:	learn: 1.1150552	total: 1.88s	remaining: 16.8s
# 141:	learn: 1.1137278	total: 1.9s	remaining: 16.8s
# 142:	learn: 1.1117040	total: 1.91s	remaining: 16.8s
# 143:	learn: 1.1098654	total: 1.93s	remaining: 16.8s
# 144:	learn: 1.1084043	total: 1.94s	remaining: 16.8s
# 145:	learn: 1.1064810	total: 1.96s	remaining: 16.8s
# 146:	learn: 1.1050459	total: 1.97s	remaining: 16.8s
# 147:	learn: 1.1033287	total: 1.98s	remaining: 16.8s
# 148:	learn: 1.1018586	total: 2s	remaining: 16.8s
# 149:	learn: 1.1003637	total: 2.01s	remaining: 16.8s
# 150:	learn: 1.0987972	total: 2.02s	remaining: 16.7s
# 151:	learn: 1.0975679	total: 2.04s	remaining: 16.7s
# 152:	learn: 1.0951504	total: 2.05s	remaining: 16.7s
# 153:	learn: 1.0936855	total: 2.06s	remaining: 16.7s
# 154:	learn: 1.0921282	total: 2.08s	remaining: 16.7s
# 155:	learn: 1.0907546	total: 2.09s	remaining: 16.7s
# 156:	learn: 1.0889409	total: 2.11s	remaining: 16.7s
# 157:	learn: 1.0874587	total: 2.12s	remaining: 16.7s
# 158:	learn: 1.0863346	total: 2.13s	remaining: 16.7s
# 159:	learn: 1.0851737	total: 2.15s	remaining: 16.6s
# 160:	learn: 1.0840557	total: 2.16s	remaining: 16.6s
# 161:	learn: 1.0821816	total: 2.17s	remaining: 16.6s
# 162:	learn: 1.0806517	total: 2.18s	remaining: 16.6s
# 163:	learn: 1.0796636	total: 2.2s	remaining: 16.6s
# 164:	learn: 1.0783609	total: 2.21s	remaining: 16.5s
# 165:	learn: 1.0769614	total: 2.22s	remaining: 16.5s
# 166:	learn: 1.0760569	total: 2.23s	remaining: 16.5s
# 167:	learn: 1.0746937	total: 2.25s	remaining: 16.5s
# 168:	learn: 1.0732476	total: 2.26s	remaining: 16.5s
# 169:	learn: 1.0718089	total: 2.27s	remaining: 16.4s
# 170:	learn: 1.0706502	total: 2.28s	remaining: 16.4s
# 171:	learn: 1.0689914	total: 2.3s	remaining: 16.4s
# 172:	learn: 1.0676485	total: 2.31s	remaining: 16.4s
# 173:	learn: 1.0661548	total: 2.33s	remaining: 16.4s
# 174:	learn: 1.0644732	total: 2.34s	remaining: 16.4s
# 175:	learn: 1.0632347	total: 2.35s	remaining: 16.4s
# 176:	learn: 1.0623289	total: 2.37s	remaining: 16.4s
# 177:	learn: 1.0607949	total: 2.38s	remaining: 16.4s
# 178:	learn: 1.0599336	total: 2.4s	remaining: 16.3s
# 179:	learn: 1.0584726	total: 2.41s	remaining: 16.3s
# 180:	learn: 1.0569578	total: 2.42s	remaining: 16.3s
# 181:	learn: 1.0557260	total: 2.43s	remaining: 16.3s
# 598:	learn: 0.6634109	total: 8.08s	remaining: 10.8s
# 599:	learn: 0.6626522	total: 8.1s	remaining: 10.8s
# 600:	learn: 0.6622671	total: 8.11s	remaining: 10.8s
# 601:	learn: 0.6614749	total: 8.12s	remaining: 10.8s
# 602:	learn: 0.6609991	total: 8.14s	remaining: 10.8s
# 603:	learn: 0.6606674	total: 8.15s	remaining: 10.7s
# 604:	learn: 0.6600325	total: 8.16s	remaining: 10.7s
# 605:	learn: 0.6591221	total: 8.18s	remaining: 10.7s
# 606:	learn: 0.6580983	total: 8.19s	remaining: 10.7s
# 607:	learn: 0.6574765	total: 8.21s	remaining: 10.7s
# 608:	learn: 0.6569523	total: 8.22s	remaining: 10.7s
# 609:	learn: 0.6562937	total: 8.23s	remaining: 10.7s
# 610:	learn: 0.6555854	total: 8.24s	remaining: 10.6s
# 611:	learn: 0.6552965	total: 8.26s	remaining: 10.6s
# 612:	learn: 0.6542977	total: 8.27s	remaining: 10.6s
# 613:	learn: 0.6539304	total: 8.28s	remaining: 10.6s
# 614:	learn: 0.6533652	total: 8.29s	remaining: 10.6s
# 615:	learn: 0.6527985	total: 8.31s	remaining: 10.6s
# 616:	learn: 0.6521600	total: 8.32s	remaining: 10.6s
# 617:	learn: 0.6515224	total: 8.33s	remaining: 10.5s
# 618:	learn: 0.6506492	total: 8.34s	remaining: 10.5s
# 619:	learn: 0.6496918	total: 8.36s	remaining: 10.5s
# 620:	learn: 0.6491408	total: 8.37s	remaining: 10.5s
# 621:	learn: 0.6484025	total: 8.38s	remaining: 10.5s
# 622:	learn: 0.6477305	total: 8.39s	remaining: 10.5s
# 623:	learn: 0.6474582	total: 8.4s	remaining: 10.5s
# 624:	learn: 0.6470313	total: 8.42s	remaining: 10.4s
# 625:	learn: 0.6463266	total: 8.43s	remaining: 10.4s
# 626:	learn: 0.6454791	total: 8.44s	remaining: 10.4s
# 627:	learn: 0.6446822	total: 8.45s	remaining: 10.4s
# 628:	learn: 0.6439711	total: 8.47s	remaining: 10.4s
# 629:	learn: 0.6428243	total: 8.48s	remaining: 10.4s
# 630:	learn: 0.6423132	total: 8.49s	remaining: 10.3s
# 631:	learn: 0.6417330	total: 8.51s	remaining: 10.3s
# 632:	learn: 0.6410985	total: 8.52s	remaining: 10.3s
# 633:	learn: 0.6402456	total: 8.53s	remaining: 10.3s
# 634:	learn: 0.6394494	total: 8.54s	remaining: 10.3s
# 635:	learn: 0.6388380	total: 8.56s	remaining: 10.3s
# 636:	learn: 0.6384275	total: 8.57s	remaining: 10.3s
# 637:	learn: 0.6379545	total: 8.58s	remaining: 10.2s
# 638:	learn: 0.6373378	total: 8.59s	remaining: 10.2s
# 639:	learn: 0.6364305	total: 8.6s	remaining: 10.2s
# 640:	learn: 0.6354864	total: 8.62s	remaining: 10.2s
# 641:	learn: 0.6347401	total: 8.63s	remaining: 10.2s
# 642:	learn: 0.6342382	total: 8.64s	remaining: 10.2s
# 643:	learn: 0.6336214	total: 8.65s	remaining: 10.2s
# 736:	learn: 0.5782540	total: 9.88s	remaining: 8.88s
# 737:	learn: 0.5776503	total: 9.89s	remaining: 8.87s
# 738:	learn: 0.5768587	total: 9.9s	remaining: 8.86s
# 739:	learn: 0.5759578	total: 9.91s	remaining: 8.84s
# 740:	learn: 0.5752501	total: 9.92s	remaining: 8.83s
# 741:	learn: 0.5746510	total: 9.94s	remaining: 8.81s
# 742:	learn: 0.5742477	total: 9.95s	remaining: 8.8s
# 743:	learn: 0.5733764	total: 9.96s	remaining: 8.79s
# 744:	learn: 0.5726690	total: 9.98s	remaining: 8.77s
# 745:	learn: 0.5723010	total: 9.99s	remaining: 8.76s
# 746:	learn: 0.5715876	total: 10s	remaining: 8.74s
# 747:	learn: 0.5708506	total: 10s	remaining: 8.73s
# 748:	learn: 0.5703976	total: 10s	remaining: 8.72s
# 749:	learn: 0.5700435	total: 10s	remaining: 8.7s
# 750:	learn: 0.5696054	total: 10.1s	remaining: 8.69s
# 751:	learn: 0.5690145	total: 10.1s	remaining: 8.68s
# 752:	learn: 0.5685444	total: 10.1s	remaining: 8.66s
# 753:	learn: 0.5678198	total: 10.1s	remaining: 8.65s
# 754:	learn: 0.5674080	total: 10.1s	remaining: 8.63s
# 755:	learn: 0.5667815	total: 10.1s	remaining: 8.62s
# 756:	learn: 0.5662660	total: 10.1s	remaining: 8.61s
# 757:	learn: 0.5654302	total: 10.1s	remaining: 8.59s
# 758:	learn: 0.5650244	total: 10.2s	remaining: 8.58s
# 759:	learn: 0.5644246	total: 10.2s	remaining: 8.56s
# 760:	learn: 0.5640609	total: 10.2s	remaining: 8.55s
# 761:	learn: 0.5636951	total: 10.2s	remaining: 8.54s
# 762:	learn: 0.5632896	total: 10.2s	remaining: 8.52s
# 763:	learn: 0.5623714	total: 10.2s	remaining: 8.51s
# 764:	learn: 0.5620448	total: 10.2s	remaining: 8.49s
# 765:	learn: 0.5617364	total: 10.2s	remaining: 8.48s
# 766:	learn: 0.5609742	total: 10.3s	remaining: 8.46s
# 767:	learn: 0.5603925	total: 10.3s	remaining: 8.45s
# 768:	learn: 0.5596508	total: 10.3s	remaining: 8.44s
# 769:	learn: 0.5589184	total: 10.3s	remaining: 8.42s
# 770:	learn: 0.5583604	total: 10.3s	remaining: 8.41s
# 771:	learn: 0.5575810	total: 10.3s	remaining: 8.39s
# 772:	learn: 0.5572075	total: 10.3s	remaining: 8.38s
# 773:	learn: 0.5568747	total: 10.3s	remaining: 8.36s
# 774:	learn: 0.5560368	total: 10.4s	remaining: 8.35s
# 775:	learn: 0.5555108	total: 10.4s	remaining: 8.34s
# 776:	learn: 0.5549165	total: 10.4s	remaining: 8.32s
# 777:	learn: 0.5544285	total: 10.4s	remaining: 8.31s
# 778:	learn: 0.5537829	total: 10.4s	remaining: 8.3s
# 779:	learn: 0.5533930	total: 10.4s	remaining: 8.28s
# 780:	learn: 0.5531220	total: 10.4s	remaining: 8.27s
# 781:	learn: 0.5524183	total: 10.4s	remaining: 8.25s
# 782:	learn: 0.5518832	total: 10.5s	remaining: 8.24s
# 783:	learn: 0.5515619	total: 10.5s	remaining: 8.22s
# 784:	learn: 0.5509152	total: 10.5s	remaining: 8.21s
# 785:	learn: 0.5501432	total: 10.5s	remaining: 8.2s
# 786:	learn: 0.5498047	total: 10.5s	remaining: 8.18s
# 787:	learn: 0.5492913	total: 10.5s	remaining: 8.17s
# 788:	learn: 0.5485535	total: 10.5s	remaining: 8.15s
# 789:	learn: 0.5480196	total: 10.5s	remaining: 8.14s
# 790:	learn: 0.5471249	total: 10.6s	remaining: 8.13s
# 791:	learn: 0.5465262	total: 10.6s	remaining: 8.11s
# 792:	learn: 0.5461531	total: 10.6s	remaining: 8.1s
# 793:	learn: 0.5457350	total: 10.6s	remaining: 8.08s
# 794:	learn: 0.5453054	total: 10.6s	remaining: 8.07s
# 795:	learn: 0.5446059	total: 10.6s	remaining: 8.05s
# 796:	learn: 0.5439824	total: 10.6s	remaining: 8.04s
# 797:	learn: 0.5432686	total: 10.6s	remaining: 8.03s
# 798:	learn: 0.5428848	total: 10.7s	remaining: 8.01s
# 799:	learn: 0.5425052	total: 10.7s	remaining: 8s
# 800:	learn: 0.5418869	total: 10.7s	remaining: 7.98s
# 801:	learn: 0.5413538	total: 10.7s	remaining: 7.97s
# 802:	learn: 0.5405786	total: 10.7s	remaining: 7.96s
# 803:	learn: 0.5398970	total: 10.7s	remaining: 7.94s
# 804:	learn: 0.5394493	total: 10.7s	remaining: 7.93s
# 805:	learn: 0.5387546	total: 10.7s	remaining: 7.91s
# 806:	learn: 0.5380681	total: 10.7s	remaining: 7.9s
# 807:	learn: 0.5374127	total: 10.8s	remaining: 7.88s
# 808:	learn: 0.5370022	total: 10.8s	remaining: 7.87s
# 809:	learn: 0.5365940	total: 10.8s	remaining: 7.86s
# 810:	learn: 0.5358382	total: 10.8s	remaining: 7.84s
# 811:	learn: 0.5350976	total: 10.8s	remaining: 7.83s
# 812:	learn: 0.5346679	total: 10.8s	remaining: 7.81s
# 813:	learn: 0.5343386	total: 10.8s	remaining: 7.8s
# 814:	learn: 0.5337398	total: 10.8s	remaining: 7.79s
# 815:	learn: 0.5333079	total: 10.9s	remaining: 7.77s
# 816:	learn: 0.5328293	total: 10.9s	remaining: 7.76s
# 817:	learn: 0.5323759	total: 10.9s	remaining: 7.74s
# 818:	learn: 0.5318607	total: 10.9s	remaining: 7.73s
# 819:	learn: 0.5312865	total: 10.9s	remaining: 7.71s
# 820:	learn: 0.5308477	total: 10.9s	remaining: 7.7s
# 821:	learn: 0.5302113	total: 10.9s	remaining: 7.69s
# 822:	learn: 0.5297683	total: 10.9s	remaining: 7.67s
# 823:	learn: 0.5293945	total: 11s	remaining: 7.66s
# 824:	learn: 0.5286606	total: 11s	remaining: 7.65s
# 825:	learn: 0.5281316	total: 11s	remaining: 7.63s
# 826:	learn: 0.5274531	total: 11s	remaining: 7.62s
# 827:	learn: 0.5268817	total: 11s	remaining: 7.61s
# 828:	learn: 0.5261758	total: 11s	remaining: 7.59s
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0103
#
#                     &plusmn; 0.0059
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 20191004_B05
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0088
#
#                     &plusmn; 0.0045
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NPCRI_20190701
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0082
#
#                     &plusmn; 0.0081
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 20190825_B09
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 82.98%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0082
#
#                     &plusmn; 0.0024
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AVI_20190701
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0079
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 area
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.42%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0079
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 20190606_B02
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0076
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AVI_20190711
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0073
#
#                     &plusmn; 0.0052
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num_pixels
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.33%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0073
#
#                     &plusmn; 0.0056
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NDVI_std
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0067
#
#                     &plusmn; 0.0036
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NPCRI_20190805
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0067
#
#                     &plusmn; 0.0049
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 20190909_B06
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0067
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 AVI_20190706
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0067
#
#                     &plusmn; 0.0024
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 EVI_20190711
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0064
#
#                     &plusmn; 0.0023
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 row_size
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0064
#
#                     &plusmn; 0.0056
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NPCRI_20190706
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.73%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0064
#
#                     &plusmn; 0.0045
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 20190701_B08
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0058
#
#                     &plusmn; 0.0030
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 20190706_B08
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0058
#
#                     &plu

# %%
pi_results = eli5.formatters.as_dataframe.explain_weights_df(pi, feature_names = train_X_all.columns.tolist())

# %%
# feature importance weigth threshold is 0
low_importance = pi_results[pi_results.weight <= 0].feature.values

# %%
low_importance
# Out:
# numpy.ndarray

# %% [markdown]
# ## Drop below features based on Permutation Importance (PI) performed above
# > NB: Features returned by the PI above may not be the same as the features I decided to eventually drop due to subjective reasons

# %%
features_to_drop = [
    '20190815_CLD', '20191004_CLD', '20190919_CLD', '20190701_CLD',
    '20190924_CLD', '20190706_CLD', 'SI_avg', '20190606_B07',
    'BSI_max', 'BSI_20191103', '20190805_B04', '20191004_B03',
    'SI_std', 'NPCRI_20190606', '20190919_B03', '20190805_B08',
    'NPCRI_20190909', 'EVI_min', '20190721_B07', '20190711_B07',
    '20190721_B05', 'AVI_20191103', 'SI_20190924', '20190805_B09',
    '20190706_B09', 'EVI_20191004', 'EVI_20190711', '20191004_B08',
    'NDVI_20191004', '20190825_B8A', '20190919_B01', '20190805_B06',
    'GNDVI_20190706', 'SI_20190805', 'EVI2_20190805', '20190706_B11',
    'col_size', '20190701_B04', 'GNDVI_20191004', 'GNDVI_20190924',
    'NPCRI_max', 'EVI_20190701', 'BSI_20190711', '20190805_B12',
    'SI_20191103', '20190919_B04', 'NDMI_20190924', 'BSI_avg',
    'NPCRI_20190706', '20190919_B8A', '20190909_B05', '20190706_B06',
    'GNDVI_20190606', '20190924_B8A', 'NDWI_20190701', 'AVI_avg',
    'GNDVI_20190919', 'NDVI_20190606', 'NDVI_20191103', 'SI_20190919',
    'GNDVI_20190721', 'NPCRI_20190721', '20190919_B09', '20190606_B01',
    '20190825_B05', '20190909_B09', '20191004_B01', '20190805_B03',
    'GNDVI_20191103', 'NPCRI_20190919', 'EVI_20190805', '20190706_B07',
    '20190909_CLD', '20190825_B12', '20190606_B06', '20190909_B07',
    'BSI_20190825', '20190805_B8A', '20190924_B09', '20190701_B07',
    'EVI2_20190721', 'NPCRI_20190805'
]

# %%
train_X_all = train_X_all.drop(columns = features_to_drop)
df_all_test = df_all_test.drop(columns = features_to_drop)

# %% [markdown]
# ## MODELLING
#
# cb = Catboost model - Dataframe 1
# cb2 = Catboost (with class weights) -  Dataframe 1
#
# cb_pixels = Catboost -  Dataframe 2
# cb2_pixels = Catboost (with class weights) -  Dataframe 2
#
# lda = LinearDiscriminantAnalysis model
# bc = BaggingClassifier (Bagged Ensemble) with lda as it's base estimator
#
# **NB: Catboost is trained with GPU enabled**

# %%
cb = CatBoostClassifier(n_estimators = 1500, learning_rate=0.03, depth = 6, random_state = 11, bagging_temperature = 1, task_type = "GPU")
# Use "class_weights = label_weights1" for cross validation
cb2 = CatBoostClassifier(n_estimators = 1100, learning_rate=0.03, depth = 6, random_state = 11, bagging_temperature = 1, task_type = "GPU", class_weights = label_weights2)

cb_pixels = CatBoostClassifier(n_estimators = 1500, learning_rate=0.03, depth = 6, random_state = 11, bagging_temperature = 1, task_type = "GPU")
# Use "class_weights = label_weights1" for cross validation
cb2_pixels = CatBoostClassifier(n_estimators = 1100, learning_rate=0.03, depth = 6, random_state = 11, bagging_temperature = 1, task_type = "GPU", class_weights = label_weights2)

lda = LinearDiscriminantAnalysis()
bc = BaggingClassifier(base_estimator = lda, n_estimators = 30, random_state = 0)

# %% [markdown]
# ## Cross Validation (CV)
# Cross validation is also used to determine weights to be applied to the average (weighted averga) of models ensembled later on.

# %% [markdown]
# ## CV with 1st DataFrame

# %%
# Catboost
cv_all_1 = cross_val_predict(cb, train_X_all, train_y_all, cv = 5, method = "predict_proba", verbose = 5)

# %%
# Catboost with weights
cv_all_2 = cross_val_predict(cb2, train_X_all, train_y_all, cv = 5, method = "predict_proba", verbose = 5)

# %%
# Bagged LDA
cv_all_3 = cross_val_predict(bc, train_X_all, train_y_all, cv = 5, method = "predict_proba", verbose = 5)

# %%
# Weighted Average of above 3 (in two steps)
cv_all_1_2 = (0.72 * cv_all_1) + ((1 - 0.72) * cv_all_2)
cv_all_1_2_3 = (0.7 * cv_all_1_2) + ((1 - 0.7) * cv_all_3)

# %% [markdown]
# ## CV with 2nd DataFrame

# %%
# Catboost
cv_pixels_1 = cross_val_predict(cb_pixels, train_X_pixels, train_y_pixels, cv = 5, method = "predict_proba", verbose = 5)

# %%
# Catboost with weights
cv_pixels_2 = cross_val_predict(cb2_pixels, train_X_pixels, train_y_pixels, cv = 5, method = "predict_proba", verbose = 5)

# %%
# Bagged LDA
cv_pixels_3 = cross_val_predict(bc, train_X_pixels, train_y_pixels, cv = 5, method = "predict_proba", verbose = 5)

# %%
# Weighted Average of above 3 (in two steps)
cv_pixels_1_2 = (0.76 * cv_pixels_1) + ((1 - 0.76) * cv_pixels_2)
cv_pixels_1_2_3 = (0.67 * cv_pixels_1_2 ) + ((1 - 0.67) * cv_pixels_3)

# %%
# Code to determine weights
scores = []

for w in range(0, 100):
    w = w / 100.
#     two cross-validation results of choice should be imputed to determine appropriate weights
    scores.append(log_loss(train_y_all, (w * cv_all_1_2_3) + ((1 - w) * cv_pixels_1_2_3)))

best_score = min(scores)
weight = scores.index(best_score) / 100.

print(weight, best_score)

# %% [markdown]
# # TRAINING

# %% [markdown]
# ## Modelling Architecture - Explanation
#
# The two different datasets each have the same model pipeline.
#
# For each of the datasets:
# ### Level 1
# Training is done using both a CatboostClassifier (without class_weights), and another CatboostClassifier (with class_weights), denoted by "cb" and "cb2" respectively.
# The weighted average of the predictions from both classifiers are obtained, using:
# 1. 72% of cb,  and 28% of cb2 for dataset 1;
# 2. 76% of cb, and 24% of cb2 for dataset 2
#
# ### Level 2
# The model used for training here is a bagged ensemble (using sklearn's BaggingClassifier), with the LinearDiscriminantAnalysis alogrithm as the base estimator.
# The predicitons from the bagged classifier is then averaged (weighted) with the individual results from level 1, using:
# 1. 70% of level 1, and 30% of bagged classifier for dataset 1;
# 2. 67% of level 1, and 33% of bagged classifier for dataset 2
#
# ### Level 3
# This level simply finds the weighted average of the final predictions from both datasets.
# It takes 68% of the final predictions from dataset 1, and 32% from dataset 2.

# %% [markdown]
# ## 1st part of model - using dataset 1

# %%
cb.fit(train_X_all, train_y_all)

# %%
cb2.fit(train_X_all, train_y_all)

# %%
bc.fit(train_X_all, train_y_all)

# %% [markdown]
# ### Predictions

# %%
test_preds_all_1 = cb.predict_proba(df_all_test)
test_preds_all_2 = cb2.predict_proba(df_all_test)
test_preds_all_3 = bc.predict_proba(df_all_test)

# %% [markdown]
# ### Weighted Average

# %%
# Level 1
test_preds_all = (0.72 * test_preds_all_1) + ((1 - 0.72) * test_preds_all_2)
# Level 2
test_preds_all = (0.7 * test_preds_all) + ((1 - 0.7) * test_preds_all_3)

# %% [markdown]
# ## 2nd part of model - using dataset 2

# %%
cb_pixels.fit(train_X_pixels, train_y_pixels)

# %%
cb2_pixels.fit(train_X_pixels, train_y_pixels)

# %%
bc.fit(train_X_pixels, train_y_pixels)

# %% [markdown]
# ### Predictions

# %%
test_preds_pixels_1 = cb_pixels.predict_proba(df_pixels_test)
test_preds_pixels_2 = cb2_pixels.predict_proba(df_pixels_test)
test_preds_pixels_3 = bc.predict_proba(df_pixels_test)

# %% [markdown]
# ### Weighted Average

# %%
# Level 1
test_preds_pixels = (0.76 * test_preds_pixels_1) + ((1 - 0.76) * test_preds_pixels_2)
# Level 2
test_preds_pixels = (0.67 * test_preds_pixels) + ((1 - 0.67) * test_preds_pixels_3)

# %% [markdown]
# ## Final Predictions - Weighted Average of 2 parts

# %%
# Level 3
test_preds = (0.68 * test_preds_all) + ((1 - 0.68) * test_preds_pixels)

# %% [markdown]
# ### Convert to DataFrame

# %%
test_preds = pd.DataFrame(test_preds)

# %% [markdown]
# ### Merge predictions with Sample Submission format

# %%
sample_submission.Crop_ID_1 = test_preds[0]
sample_submission.Crop_ID_2 = test_preds[1]
sample_submission.Crop_ID_3 = test_preds[2]
sample_submission.Crop_ID_4 = test_preds[3]
sample_submission.Crop_ID_5 = test_preds[4]
sample_submission.Crop_ID_6 = test_preds[5]
sample_submission.Crop_ID_7 = test_preds[6]

# %%
sample_submission.head()

# %% [markdown]
# ### Export

# %%
sample_submission.to_csv("SampleSub.csv", index = False)
